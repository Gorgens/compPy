# %% [markdown]
# # Introdução
#
# Autor: Eric Bastos Gorgens
#
# 1ª Edição
#
# Ano 2020

# %% [markdown]
# ## Collaboratory
#
# Criando um *notebook*...
#
# Importanto uma base de dados externa...
#
# Integrando o notebook com o Google Drive...

# %% [markdown]
# ## Módulos
#
# Instalando novos módulos no Colab...
#
# Ativando um módulo (importar)...

# %% [markdown]
# ## Métodos
#
# Chamando um método...

# %% [markdown]
# ## Funções
